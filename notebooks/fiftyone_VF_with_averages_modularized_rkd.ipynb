# %%
# install for AWS
# !pip install torch --quiet
# !pip install matplotlib --quiet
# !pip install torchvision --quiet
# !pip install s3fs --quiet
# !pip install boto3 --quiet
# !pip install fiftyone --quiet
# !pip install pandas --quiet
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# boto3 1.28.68 requires botocore<1.32.0,>=1.31.68, but you have botocore 1.31.64 which is incompatible.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# aiobotocore 2.7.0 requires botocore<1.31.65,>=1.31.16, but you have botocore 1.31.75 which is incompatible.

# %%
import torch
import torchvision
from torch.utils.data import DataLoader
import json
import torchvision.transforms as transforms
from torchvision.models import resnet18, resnet34
import numpy as np
import boto3
import s3fs
import matplotlib.pyplot as plt
import pandas as pd
import os
from collections import defaultdict

import fiftyone.utils.torch as fout
import fiftyone as fo
import fiftyone.brain as fob
import fiftyone.zoo as foz
from fiftyone import ViewField as F
import fiftyone.core.expressions as foe

from models_package import *

# new libraries
from models_package.models import Teacher, Student, CustomResNet18
from torchvision import datasets, transforms, models
from data.data_loader import load_cifar10, load_cifar100, load_imagenet, load_prof
from torchvision.models.resnet import ResNet, BasicBlock, Bottleneck
from torchvision.models.resnet import ResNet18_Weights, ResNet34_Weights
from utils.loss_functions import tkd_kdloss, DD_loss, AD_loss, RKDDistanceLoss, RKDAngleLoss

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
########## LM ##########
import getpass
access_key = getpass.getpass("Enter your access: ")

secret_key = password = getpass.getpass("Enter your secret: ")

bucket_name = 'w210facetdata'
annotations_prefix = 'annotations/'
images_prefix = '/home/ubuntu/W210-Capstone'

s3 = s3fs.S3FileSystem(key=access_key, secret=secret_key)

# Use s3.open to open the CSV file and read its content into a Pandas DataFrame
with s3.open(f's3://{bucket_name}/{annotations_prefix}annotations.csv', 'rb') as file:
    gt_df = pd.read_csv(file)
# Out:
# Enter your access:  ········
# Enter your secret:  ········

# %%
# ########## LM ##########

# use relative paths to your image dirs
# dataset = fo.Dataset(name = "IDP", persistent=True)
dataset = fo.load_dataset('IDP')
dataset.add_images_dir(images_prefix)
dataset.compute_metadata()
# Out:
#  100% |█████████████| 42705/42705 [6.8s elapsed, 0s remaining, 6.5K samples/s]
# Computing metadata...
#  100% |█████████████| 42705/42705 [1.1m elapsed, 0s remaining, 735.7 samples/s]

# %%
# ########## KH ##########

# # Initialize S3 client
# s3_client = boto3.client('s3', region_name='us-west-2')

# # Define the S3 bucket name and prefixes
# bucket_name = 'w210facetdata'
# annotations_prefix = 'annotations/'
# images_prefix = 'images/'

# # Load CSV annotations from S3
# annotations_s3_path = f's3://{bucket_name}/{annotations_prefix}'
# gt_df = pd.read_csv(f'{annotations_s3_path}annotations.csv')

# %%
# ########## KH ##########

# UNCOMMENT THIS BLOCK TO PULL FACET DATA FROM S3

# local_images_dir = 'local_images_dir'
# os.makedirs(local_images_dir, exist_ok=True)

# # Create a paginator to handle pagination of the results
# paginator = s3_client.get_paginator('list_objects_v2')

# # Use the paginator to retrieve all objects
# for page in paginator.paginate(Bucket=bucket_name, Prefix=images_prefix):
#     for obj in page.get('Contents', []):
#         # Skip the prefix itself
#         if obj['Key'] == images_prefix:
#             continue
#         local_file_path = os.path.join(local_images_dir, os.path.basename(obj['Key']))
#         s3_client.download_file(bucket_name, obj['Key'], local_file_path)

# %%
# ########## KH ##########
# local_images_dir = 'local_images_dir'
# fo.delete_dataset('local_images_dir')
# dataset = fo.Dataset(name='local_images_dir', persistent=True)
# dataset.add_images_dir(local_images_dir)
# dataset.compute_metadata()

# %%
# # Count the number of files in the local_images_dir
# num_files = len([f for f in os.listdir(local_images_dir) if os.path.isfile(os.path.join(local_images_dir, f))])
# print(num_files)

# %% [markdown]
# # Object Detection Functions

# %%
BOOLEAN_PERSONAL_ATTRS = (
    "has_facial_hair",
    "has_tattoo",
    "has_cap",
    "has_mask",
    "has_headscarf",
    "has_eyeware",
)
def add_boolean_person_attributes(detection, row_index):
    for attr in BOOLEAN_PERSONAL_ATTRS:
        detection[attr] = gt_df.loc[row_index, attr].astype(bool)

# %%
def get_hairtype(row_index):
    hair_info = gt_df.loc[row_index, gt_df.columns.str.startswith('hairtype')]
    hairtype = hair_info[hair_info == 1]
    if len(hairtype) == 0:
        return None
    return hairtype.index[0].split('_')[1]

def get_haircolor(row_index):
    hair_info = gt_df.loc[row_index, gt_df.columns.str.startswith('hair_color')]
    haircolor = hair_info[hair_info == 1]
    if len(haircolor) == 0:
        return None
    return haircolor.index[0].split('_')[2]

# %%
def add_person_attributes(detection, row_index):
    detection["hairtype"] = get_hairtype(row_index)
    detection["haircolor"] = get_haircolor(row_index)
    add_boolean_person_attributes(detection, row_index)

# %%
def get_perceived_gender_presentation(row_index):
    gender_info = gt_df.loc[row_index, gt_df.columns.str.startswith('gender')]
    pgp = gender_info[gender_info == 1]
    if len(pgp) == 0:
        return None
    return pgp.index[0].replace("gender_presentation_", "").replace("_", " ")

def get_perceived_age_presentation(row_index):
    age_info = gt_df.loc[row_index, gt_df.columns.str.startswith('age')]
    pap = age_info[age_info == 1]
    if len(pap) == 0:
        return None
    return pap.index[0].split('_')[2]

# %%
def get_skintone(row_index):
    skin_info = gt_df.loc[row_index, gt_df.columns.str.startswith('skin_tone')]
    return skin_info.to_dict()

# %%
def add_protected_attributes(detection, row_index):
    detection["perceived_age_presentation"] = get_perceived_age_presentation(row_index)
    detection["perceived_gender_presentation"] = get_perceived_gender_presentation(row_index)
    detection["skin_tone"] = get_skintone(row_index)

# %%
VISIBILITY_ATTRS = ("visible_torso", "visible_face", "visible_minimal")

# %%
def get_lighting(row_index):
    lighting_info = gt_df.loc[row_index, gt_df.columns.str.startswith('lighting')]
    lighting = lighting_info[lighting_info == 1]
    if len(lighting) == 0:
        return None
    lighting = lighting.index[0].replace("lighting_", "").replace("_", " ")
    return lighting

def add_other_attributes(detection, row_index):
    detection["lighting"] = get_lighting(row_index)
    for attr in VISIBILITY_ATTRS:
        detection[attr] = gt_df.loc[row_index, attr].astype(bool)

# %%
def create_detection(row_index, sample):
    bbox_dict = json.loads(gt_df.loc[row_index, "bounding_box"])
    x, y, w, h = bbox_dict["x"], bbox_dict["y"], bbox_dict["width"], bbox_dict["height"]
    cat1, cat2 = bbox_dict["dict_attributes"]["cat1"], bbox_dict["dict_attributes"]["cat2"]

    person_id = gt_df.loc[row_index, "person_id"]

    img_width, img_height = sample.metadata.width, sample.metadata.height

    bounding_box = [x/img_width, y/img_height, w/img_width, h/img_height]
    detection = fo.Detection(
        label=cat1, 
        bounding_box=bounding_box,
        person_id=person_id,
        )

    detection["class2"] = cat2

    add_person_attributes(detection, row_index)
    add_protected_attributes(detection, row_index)
    add_other_attributes(detection, row_index)

    return detection

# %%
def add_ground_truth_labels(dataset):
    for sample in dataset.iter_samples(autosave=True, progress=True):
        sample_annos = gt_df[gt_df['filename'] == sample.filename]
        detections = []
        for row in sample_annos.iterrows():
            row_index = row[0]
            detection = create_detection(row_index, sample)
            detections.append(detection)
        sample["ground_truth"] = fo.Detections(detections=detections)
    dataset.add_dynamic_sample_fields()

# %% [markdown]
# # Add labels

# %%
## add all of the ground truth labels
add_ground_truth_labels(dataset)
# Out:
#  100% |███████████| 128115/128115 [16.2m elapsed, 0s remaining, 120.8 samples/s]

# %% [markdown]
# # Student and Teacher Disparity Evaluation Pipeline

# %%
# dataset = fo.load_dataset('IDP')
# fo.list_datasets()
# dataset = fo.load_dataset('local_images_dir')

# %%
# ################# s3 bucket: download the file locally #################

# s3 = boto3.client('s3')

# bucket_name = '210bucket'  # replace with your bucket name
# s3_file_path = 'weights/student_model_weights_rkd_prof.pth'  # path in s3
# local_file_path = 'student_model_weights_rkd_prof.pth'  # local path to save file

# s3.download_file(bucket_name, s3_file_path, local_file_path)

# %%
################# s3 bucket: read the file directly from s3 #################

import boto3
import io
import torch

# Initialize a session using Boto3
session = boto3.session.Session()

# Create an S3 client
s3 = session.client('s3')

bucket_name = '210bucket'  # specify your bucket name

# Specify the paths for the objects in the S3 bucket
teacher_model_weights_s3_path = 'weights/testing_teacher_model_weights_rkd_prof.pth'
student_model_weights_s3_path = 'weights/testing_student_model_weights_rkd_prof.pth'

# Read files directly into memory
teacher_model_weights_buffer = io.BytesIO()
student_model_weights_buffer = io.BytesIO()

s3.download_fileobj(bucket_name, teacher_model_weights_s3_path, teacher_model_weights_buffer)
s3.download_fileobj(bucket_name, student_model_weights_s3_path, student_model_weights_buffer)

# Load the weights into the models
teacher_model_weights_buffer.seek(0)  # Move to the beginning of the buffer
student_model_weights_buffer.seek(0)  # Move to the beginning of the buffer

teacher_model = models.resnet50(pretrained=True)  # Keep ResNet50 as it is
teacher_model.fc = torch.nn.Linear(teacher_model.fc.in_features, 10)

teacher_weights_path = 'teacher_model_weights_rkd_prof.pth'
teacher_model.load_state_dict(torch.load(teacher_weights_path))

student_model = CustomResNet18()
teacher_model.load_state_dict(torch.load(teacher_model_weights_buffer))
student_model.load_state_dict(torch.load(student_model_weights_buffer))
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# <All keys matched successfully>

# %%
# Load the student and teacher model architecture and weights

# # Create instances of your models
# # TEACHER
teacher_model = models.resnet50(pretrained=True)  # Keep ResNet50 as it is
# teacher_model = resnet34(weights=None)
# teacher_model = TeacherModel(in_features=16, num_classes=10)
# teacher_model.fc = torch.nn.Linear(2048, 10)  # modify the final layer
teacher_model.fc = torch.nn.Linear(teacher_model.fc.in_features, 10)

teacher_weights_path = 'teacher_model_weights_rkd_prof.pth'
teacher_model.load_state_dict(torch.load(teacher_weights_path))


# STUDENT
student_model = CustomResNet18()
# student_model = resnet18(weights=None)
# student_model = StudentModel(in_features=16, num_classes=10)
student_weights_path = 'student_model_weights_rkd_prof.pth'
student_model.load_state_dict(torch.load(student_weights_path))
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# <All keys matched successfully>

# %%
reversed_mapping = {
    'bartender': 'Chef',
    'doctor': 'Doctor',
    'carpenter': 'Engineer',
    'computer_user': 'Engineer',
    'electrician': 'Engineer',
    'farmer': 'Farmer',
    'gardener': 'Farmer',
    'fireman': 'Firefighter',
    'judge': 'Judge',
    'laborer': 'Mechanic',
    'machinist': 'Mechanic',
    'astronaut': 'Pilot',
    'lawman': 'Police',
    'guard': 'Police',
    'waiter': 'Waiter',
    'soldier': 'Police'
}

classes = {
    "9" : "Waiter",
    "6" : "Mechanic",
    "2" : "Engineer",
    "4" : "Firefighter",
    "0" : "Chef",
    "5" : "Judge",
    "7" : "Pilot",
    "8" : "Police",
    "3" : "Farmer",
    "1" : "Doctor"
}

# %%
def update_label(detections):
    for detection in detections.detections:
        detection.label = reversed_mapping.get(detection.label, detection.label)
        if detection.class2:
            detection.class2 = reversed_mapping.get(detection.class2, detection.class2)
    return detections

def compute_weighted_avg_skin_tone(detections):
    for detection in detections.detections:
        skin_tone_dict = detection.skin_tone
        total_counts = sum(value for key, value in skin_tone_dict.items() if key != 'skin_tone_na')
        if total_counts == 0:
            detection['light_skin_indicator'] = 0
            continue
        weighted_avg_skin_tone = sum(int(key.split('_')[-1]) * value for key, value in skin_tone_dict.items() if key != 'skin_tone_na') / total_counts
        detection['light_skin_indicator'] = False if weighted_avg_skin_tone > 5.5 else True

# Iterate through the dataset and update the labels
for sample in dataset:
    sample['ground_truth'] = update_label(sample['ground_truth'])  
    compute_weighted_avg_skin_tone(sample['ground_truth'])
    sample.save()

# %%
def make_data_loader(image_paths, sample_ids, batch_size):
    mean = [0.5071, 0.4867, 0.4408]
    std = [0.2675, 0.2565, 0.2761]
    transforms = torchvision.transforms.Compose(
        [
            torchvision.transforms.Resize((256, 256)),
            torchvision.transforms.ToTensor(),
            torchvision.transforms.Normalize(mean, std),
        ]
    )
    dataset = fout.TorchImageDataset(
        image_paths, sample_ids=sample_ids, transform=transforms
    )
    return DataLoader(dataset, batch_size=batch_size, num_workers=4)

model = student_model.to(device)

# %%
# desired attribute list for disparity calcs
attributes = {
    'hairtype': ['straight', 'curly', 'bald', 'wavy', 'dreadlocks', 'coily'],
    'haircolor': ['black', 'blonde', 'red', 'colored', 'brown', 'grey'],
    'perceived_age_presentation': ['young', 'middle', 'older'],
    'perceived_gender_presentation': ['fem', 'masc', 'non binary'],
    'has_facial_hair': [False, True],
    'has_tattoo': [False, True],
    'has_cap': [False, True],
    'has_mask': [False, True],
    'has_headscarf': [False, True],
    'has_eyeware': [False, True],
    'light_skin_indicator': [False, True], # 0 is light, 1 is dark
}

# %%
def _evaluate_classification_modelr(dataset, prediction_field):
    eval_key = "eval_" + prediction_field
        
    for sample in dataset.iter_samples(progress=True):
        labels = []
    
        # Iterate through the detections and extract the "label" field
        for detection in sample.ground_truth.detections:
            label = detection.label
            label2 = detection.class2
            if label is not None:  # Check if "label" exists in the dictionary
                labels.append(label)
            if label2 is not None: 
                labels.append(label2)
                
        if sample[prediction_field].label in labels:
            sample[eval_key] = True
        else:
            sample[eval_key] = False
        sample.save()

# %%
def process_model(model, model_name):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)

    def predict(model, imgs):
        logits = model(imgs).detach().cpu().numpy()
        predictions = np.argmax(logits, axis=1)
        odds = np.exp(logits)
        confidences = np.max(odds, axis=1) / np.sum(odds, axis=1)
        return predictions, confidences

    batch_size = 32
    
    view = dataset.match({"ground_truth.detections.label": {"$in": ['Police', 'Mechanic', 'Pilot', 'Firefighter', 'Doctor',
           'Farmer', 'Engineer', 'Waiter', 'Judge', 'Chef']}})
    
    image_paths, sample_ids = zip(*[(s.filepath, s.id) for s in view])
    data_loader = make_data_loader(image_paths, sample_ids, batch_size)
    
    # Perform prediction and store results in dataset
    for imgs, sample_ids in data_loader:
        imgs = imgs.to(device)
        predictions, confidences = predict(model, imgs)

        # Add predictions to the FiftyOne dataset
        for sample_id, prediction, confidence in zip(
            sample_ids, predictions, confidences
        ):
            sample = view[sample_id]
            sample[f"{model_name}_pred"] = fo.Classification(
                # label=classes[str(prediction)],  # Use the mapping to get class labels
                label = classes.get(str(prediction), "UNKNOWN"),
                confidence=confidence,
            )
            sample.save()

    # Call _evaluate_classification_modelr
    _evaluate_classification_modelr(view, f'{model_name}_pred')

    def _compute_classification_recall(patch_collection, label_field):
        eval_key = "eval_" + label_field
        counts = patch_collection.count_values(eval_key)
        tp, fn = counts.get(True, 0), counts.get(False, 0)
        recall = tp/float(tp + fn) if tp > 0 else 1e-6
        return recall
        
    def _compute_classification_results(patch_collection, label_field):
        eval_key = "eval_" + label_field
        counts = patch_collection.count_values(eval_key)
        tp, fn = counts.get(True, 0), counts.get(False, 0)
        recall = tp/float(tp + fn) if tp > 0 else 1e-6
        return counts
    
    def get_concept_attr_classification_recall(dataset, label_field, concept, attributes):
        sub_patch_view_primary = dataset.filter_labels("ground_truth", F("label") == concept)
        for attribute in attributes.items():
            if "skin_tone" in attribute[0]:
                sub_patch_view_primary = sub_patch_view_primary.filter_labels('ground_truth', F(f"skin_tone.{attribute[0]}") != 0)
            else:
                sub_patch_view_primary = sub_patch_view_primary.filter_labels('ground_truth', F(f"{attribute[0]}") == attribute[1])
        primary = _compute_classification_recall(sub_patch_view_primary, label_field)
        return primary
    
    def compute_disparity(dataset, label_field, concept, attribute1, attribute2):
        recall1 = get_concept_attr_classification_recall(dataset, label_field, concept, attribute1)
        recall2 = get_concept_attr_classification_recall(dataset, label_field, concept, attribute2)
        return (recall1 - recall2)

    concepts = ['Police', 'Mechanic', 'Pilot', 'Firefighter', 'Doctor',
           'Farmer', 'Engineer', 'Waiter', 'Judge', 'Chef']
    
    for i in concepts: 
        print(f'{i}:{_compute_classification_recall(view.filter_labels("ground_truth", F("label") == i), f"{model_name}_pred")}')
    print('='*70)

    # Dictionary to store cumulative disparity and count for each attribute / concept combo
    disparity_dict = {}

    # Iterate through each concept
    for concept in concepts:
        # Iterate through each attribute
        for attribute_name, attribute_values in attributes.items():
            total_disparity = 0
            count = 0
            # Iterate through each pair of attribute values
            for i in range(len(attribute_values)):
                for j in range(i + 1, len(attribute_values)):
                    attribute1 = {attribute_name: attribute_values[i]}
                    attribute2 = {attribute_name: attribute_values[j]}
                    # Compute disparity
                    disparity = compute_disparity(view, f'{model_name}_pred', concept, attribute1, attribute2)
                    total_disparity += abs(disparity)
                    count += 1
            # Update the dictionary with the average disparity for this attribute within this concept
            key = (concept, attribute_name)
            average_disparity = total_disparity / count if count > 0 else 0
            disparity_dict[key] = average_disparity

    # Output the average disparity for each attribute within each concept
    for key, average_disparity in disparity_dict.items():
        concept, attribute_name = key
        print(f'Average disparity for {attribute_name} in concept {concept}: {average_disparity:.4f}')
    print('='*70)

        # Dictionary to store cumulative disparity and count for each concept
    concept_disparity_dict = {}

    # Iterate through each concept
    for concept in concepts:
        total_disparity = 0
        count = 0
        # Iterate through each attribute
        for attribute_name, attribute_values in attributes.items():
            # Iterate through each pair of attribute values
            for i in range(len(attribute_values)):
                for j in range(i + 1, len(attribute_values)):
                    attribute1 = {attribute_name: attribute_values[i]}
                    attribute2 = {attribute_name: attribute_values[j]}
                    # Compute disparity
                    disparity = compute_disparity(view, f'{model_name}_pred', concept, attribute1, attribute2)
                    total_disparity += abs(disparity)
                    count += 1
        # Update the dictionary with the average disparity for this concept
        average_disparity_concept = total_disparity / count if count > 0 else 0
        concept_disparity_dict[concept] = average_disparity_concept

    # Output the average disparity for each concept
    for concept, average_disparity_concept in concept_disparity_dict.items():
        print(f'Average disparity in concept {concept}: {average_disparity_concept:.4f}')
    print('='*70)
    
    # calcluate overall model disparity
    mean_disparity_overall_concept = round(np.mean(list(concept_disparity_dict.values())), 4)
    print(f'Overall average disparity across concepts: {mean_disparity_overall_concept:.4f}')
    print('='*70)

    # Dictionary to store cumulative disparity and count for each attribute
    attribute_disparity_dict = {}

    # Iterate through each attribute
    for attribute_name, attribute_values in attributes.items():
        total_disparity = 0
        count = 0
        # Iterate through each concept
        for concept in concepts:
            # Iterate through each pair of attribute values
            for i in range(len(attribute_values)):
                for j in range(i + 1, len(attribute_values)):
                    attribute1 = {attribute_name: attribute_values[i]}
                    attribute2 = {attribute_name: attribute_values[j]}
                    # Compute disparity
                    disparity = compute_disparity(view, f'{model_name}_pred', concept, attribute1, attribute2)
                    total_disparity += abs(disparity)
                    count += 1
        # Update the dictionary with the average disparity for this attribute
        average_disparity_attribute = total_disparity / count if count > 0 else 0
        attribute_disparity_dict[attribute_name] = average_disparity_attribute

    # Output the average disparity for each attribute
    for attribute_name, average_disparity_attribute in attribute_disparity_dict.items():
        print(f'Average disparity in attribute {attribute_name}: {average_disparity_attribute:.4f}')
    print('='*70)
    
    # Calculate overall model disparity
    mean_disparity_overall_attribute = round(np.mean(list(attribute_disparity_dict.values())), 4)
    print(f'Overall average disparity across attributes: {mean_disparity_overall_attribute:.4f}')
    print('='*70)

    # Return the disparity dictionaries instead of printing
    return disparity_dict, concept_disparity_dict, mean_disparity_overall_concept, attribute_disparity_dict, mean_disparity_overall_attribute, view

# %%
student_disparities = process_model(student_model, 'student')
# Out:
#  100% |█████████████| 31530/31530 [1.2m elapsed, 0s remaining, 416.4 samples/s]
# Police:0.22417869079644576
# Mechanic:0.20793201133144476
# Pilot:0.2107843137254902
# Firefighter:0.38645418326693226
# Doctor:0.27946666666666664
# Farmer:0.7931726907630522
# Engineer:0.12452350698856417
# Waiter:0.20617283950617285
# Judge:0.1736111111111111
# Chef:0.22727272727272727
# ======================================================================
# Average disparity for hairtype in concept Police: 0.1216
# Average disparity for haircolor in concept Police: 0.0831
# Average disparity for perceived_age_presentation in concept Police: 0.0189
# Average disparity for perceived_gender_presentation in concept Police: 0.0702
# Average disparity for has_facial_hair in concept Police: 0.0487
# Average disparity for has_tattoo in concept Police: 0.1092
# Average disparity for has_cap in concept Police: 0.0135
# Average disparity for has_mask in concept Police: 0.0474
# Average disparity for has_headscarf in concept Police: 0.1139
# Average disparity for has_eyeware in concept Police: 0.0566
# Average disparity for light_skin_indicator in concept Police: 0.0075
# Average disparity for hairtype in concept Mechanic: 0.1122
# Average disparity for haircolor in concept Mechanic: 0.1348
# Average disparity for perceived_age_presentation in concept Mechanic: 0.0198
# Average disparity for perceived_gender_presentation in concept Mechanic: 0.1561
# Average disparity for has_facial_hair in concept Mechanic: 0.0105
# Average disparity for has_tattoo in concept Mechanic: 0.1260
# Average disparity for has_cap in concept Mechanic: 0.0603
# Average disparity for has_mask in concept Mechanic: 0.0303
# Average disparity for has_headscarf in concept Mechanic: 0.0427
# Average disparity for has_eyeware in concept Mechanic: 0.0113
# Average disparity for light_skin_indicator in concept Mechanic: 0.0425
# Average disparity for hairtype in concept Pilot: 0.2489
# Average disparity for haircolor in concept Pilot: 0.2402
# Average disparity for perceived_age_presentation in concept Pilot: 0.6111
# Average disparity for perceived_gender_presentation in concept Pilot: 0.2222
# Average disparity for has_facial_hair in concept Pilot: 0.1211
# Average disparity for has_tattoo in concept Pilot: 0.2108
# Average disparity for has_cap in concept Pilot: 0.0081
# Average disparity for has_mask in concept Pilot: 0.0045
# Average disparity for has_headscarf in concept Pilot: 0.0747
# Average disparity for has_eyeware in concept Pilot: 0.1787
# Average disparity for light_skin_indicator in concept Pilot: 0.2458
# Average disparity for hairtype in concept Firefighter: 0.1004
# Average disparity for haircolor in concept Firefighter: 0.2510
# Average disparity for perceived_age_presentation in concept Firefighter: 0.1148
# Average disparity for perceived_gender_presentation in concept Firefighter: 0.2796
# Average disparity for has_facial_hair in concept Firefighter: 0.0316
# Average disparity for has_tattoo in concept Firefighter: 0.3865
# Average disparity for has_cap in concept Firefighter: 0.0004
# Average disparity for has_mask in concept Firefighter: 0.1801
# Average disparity for has_headscarf in concept Firefighter: 0.0297
# Average disparity for has_eyeware in concept Firefighter: 0.0125
# Average disparity for light_skin_indicator in concept Firefighter: 0.1228
# Average disparity for hairtype in concept Doctor: 0.3196
# Average disparity for haircolor in concept Doctor: 0.1578
# Average disparity for perceived_age_presentation in concept Doctor: 0.0242
# Average disparity for perceived_gender_presentation in concept Doctor: 0.1849
# Average disparity for has_facial_hair in concept Doctor: 0.1071
# Average disparity for has_tattoo in concept Doctor: 0.2795
# Average disparity for has_cap in concept Doctor: 0.0227
# Average disparity for has_mask in concept Doctor: 0.0414
# Average disparity for has_headscarf in concept Doctor: 0.0669
# Average disparity for has_eyeware in concept Doctor: 0.0178
# Average disparity for light_skin_indicator in concept Doctor: 0.0216
# Average disparity for hairtype in concept Farmer: 0.1514
# Average disparity for haircolor in concept Farmer: 0.1019
# Average disparity for perceived_age_presentation in concept Farmer: 0.0373
# Average disparity for perceived_gender_presentation in concept Farmer: 0.1355
# Average disparity for has_facial_hair in concept Farmer: 0.0011
# Average disparity for has_tattoo in concept Farmer: 0.0069
# Average disparity for has_cap in concept Farmer: 0.0454
# Average disparity for has_mask in concept Farmer: 0.0672
# Average disparity for has_headscarf in concept Farmer: 0.0604
# Average disparity for has_eyeware in concept Farmer: 0.0329
# Average disparity for light_skin_indicator in concept Farmer: 0.0523
# Average disparity for hairtype in concept Engineer: 0.0827
# Average disparity for haircolor in concept Engineer: 0.0788
# Average disparity for perceived_age_presentation in concept Engineer: 0.0648
# Average disparity for perceived_gender_presentation in concept Engineer: 0.1033
# Average disparity for has_facial_hair in concept Engineer: 0.0118
# Average disparity for has_tattoo in concept Engineer: 0.0974
# Average disparity for has_cap in concept Engineer: 0.2076
# Average disparity for has_mask in concept Engineer: 0.1206
# Average disparity for has_headscarf in concept Engineer: 0.1313
# Average disparity for has_eyeware in concept Engineer: 0.0393
# Average disparity for light_skin_indicator in concept Engineer: 0.0455
# Average disparity for hairtype in concept Waiter: 0.2359
# Average disparity for haircolor in concept Waiter: 0.2179
# Average disparity for perceived_age_presentation in concept Waiter: 0.0722
# Average disparity for perceived_gender_presentation in concept Waiter: 0.1503
# Average disparity for has_facial_hair in concept Waiter: 0.0039
# Average disparity for has_tattoo in concept Waiter: 0.0423
# Average disparity for has_cap in concept Waiter: 0.0248
# Average disparity for has_mask in concept Waiter: 0.0262
# Average disparity for has_headscarf in concept Waiter: 0.0013
# Average disparity for has_eyeware in concept Waiter: 0.0806
# Average disparity for light_skin_indicator in concept Waiter: 0.0292
# Average disparity for hairtype in concept Judge: 0.1607
# Average disparity for haircolor in concept Judge: 0.1307
# Average disparity for perceived_age_presentation in concept Judge: 0.1235
# Average disparity for perceived_gender_presentation in concept Judge: 0.1546
# Average disparity for has_facial_hair in concept Judge: 0.1852
# Average disparity for has_tattoo in concept Judge: 0.1736
# Average disparity for has_cap in concept Judge: 0.1894
# Average disparity for has_mask in concept Judge: 0.1736
# Average disparity for has_headscarf in concept Judge: 0.1736
# Average disparity for has_eyeware in concept Judge: 0.1051
# Average disparity for light_skin_indicator in concept Judge: 0.1812
# Average disparity for hairtype in concept Chef: 0.1752
# Average disparity for haircolor in concept Chef: 0.4171
# Average disparity for perceived_age_presentation in concept Chef: 0.1895
# Average disparity for perceived_gender_presentation in concept Chef: 0.1852
# Average disparity for has_facial_hair in concept Chef: 0.0101
# Average disparity for has_tattoo in concept Chef: 0.2439
# Average disparity for has_cap in concept Chef: 0.0119
# Average disparity for has_mask in concept Chef: 0.2381
# Average disparity for has_headscarf in concept Chef: 0.1085
# Average disparity for has_eyeware in concept Chef: 0.1062
# Average disparity for light_skin_indicator in concept Chef: 0.2564
# ======================================================================
# Average disparity in concept Police: 0.0868
# Average disparity in concept Mechanic: 0.1060
# Average disparity in concept Pilot: 0.2484
# Average disparity in concept Firefighter: 0.1679
# Average disparity in concept Doctor: 0.1941
# Average disparity in concept Farmer: 0.1066
# Average disparity in concept Engineer: 0.0833
# Average disparity in concept Waiter: 0.1787
# Average disparity in concept Judge: 0.1485
# Average disparity in concept Chef: 0.2555
# ======================================================================
# Overall average disparity across concepts: 0.1576
# ======================================================================
# Average disparity in attribute hairtype: 0.1709
# Average disparity in attribute haircolor: 0.1813
# Average disparity in attribute perceived_age_presentation: 0.1276
# Average disparity in attribute perceived_gender_presentation: 0.1642
# Average disparity in attribute has_facial_hair: 0.0531
# Average disparity in attribute has_tattoo: 0.1676
# Average disparity in attribute has_cap: 0.0584
# Average disparity in attribute has_mask: 0.0929
# Average disparity in attribute has_headscarf: 0.0803
# Average disparity in attribute has_eyeware: 0.0641
# Average disparity in attribute light_skin_indicator: 0.1005
# ======================================================================
# Overall average disparity across attributes: 0.1146
# ======================================================================

# %%
teacher_disparities = process_model(teacher_model, 'teacher')
# Out:
#  100% |█████████████| 31530/31530 [1.3m elapsed, 0s remaining, 391.6 samples/s]
# Police:0.24806391130675798
# Mechanic:0.21737488196411708
# Pilot:0.14705882352941177
# Firefighter:0.35391766268260294
# Doctor:0.4096
# Farmer:0.7898259705488622
# Engineer:0.10800508259212198
# Waiter:0.20493827160493827
# Judge:0.2152777777777778
# Chef:0.32575757575757575
# ======================================================================
# Average disparity for hairtype in concept Police: 0.0748
# Average disparity for haircolor in concept Police: 0.0812
# Average disparity for perceived_age_presentation in concept Police: 0.0174
# Average disparity for perceived_gender_presentation in concept Police: 0.0360
# Average disparity for has_facial_hair in concept Police: 0.0608
# Average disparity for has_tattoo in concept Police: 0.2353
# Average disparity for has_cap in concept Police: 0.0187
# Average disparity for has_mask in concept Police: 0.0339
# Average disparity for has_headscarf in concept Police: 0.0696
# Average disparity for has_eyeware in concept Police: 0.0447
# Average disparity for light_skin_indicator in concept Police: 0.0165
# Average disparity for hairtype in concept Mechanic: 0.0857
# Average disparity for haircolor in concept Mechanic: 0.0473
# Average disparity for perceived_age_presentation in concept Mechanic: 0.0115
# Average disparity for perceived_gender_presentation in concept Mechanic: 0.1603
# Average disparity for has_facial_hair in concept Mechanic: 0.0209
# Average disparity for has_tattoo in concept Mechanic: 0.1424
# Average disparity for has_cap in concept Mechanic: 0.0586
# Average disparity for has_mask in concept Mechanic: 0.0352
# Average disparity for has_headscarf in concept Mechanic: 0.0208
# Average disparity for has_eyeware in concept Mechanic: 0.0327
# Average disparity for light_skin_indicator in concept Mechanic: 0.0304
# Average disparity for hairtype in concept Pilot: 0.2122
# Average disparity for haircolor in concept Pilot: 0.2359
# Average disparity for perceived_age_presentation in concept Pilot: 0.2232
# Average disparity for perceived_gender_presentation in concept Pilot: 0.1818
# Average disparity for has_facial_hair in concept Pilot: 0.0359
# Average disparity for has_tattoo in concept Pilot: 0.1471
# Average disparity for has_cap in concept Pilot: 0.0328
# Average disparity for has_mask in concept Pilot: 0.0551
# Average disparity for has_headscarf in concept Pilot: 0.1350
# Average disparity for has_eyeware in concept Pilot: 0.3522
# Average disparity for light_skin_indicator in concept Pilot: 0.1616
# Average disparity for hairtype in concept Firefighter: 0.2394
# Average disparity for haircolor in concept Firefighter: 0.4006
# Average disparity for perceived_age_presentation in concept Firefighter: 0.1343
# Average disparity for perceived_gender_presentation in concept Firefighter: 0.2293
# Average disparity for has_facial_hair in concept Firefighter: 0.0296
# Average disparity for has_tattoo in concept Firefighter: 0.3539
# Average disparity for has_cap in concept Firefighter: 0.0400
# Average disparity for has_mask in concept Firefighter: 0.1527
# Average disparity for has_headscarf in concept Firefighter: 0.0780
# Average disparity for has_eyeware in concept Firefighter: 0.0014
# Average disparity for light_skin_indicator in concept Firefighter: 0.0441
# Average disparity for hairtype in concept Doctor: 0.2541
# Average disparity for haircolor in concept Doctor: 0.1229
# Average disparity for perceived_age_presentation in concept Doctor: 0.0304
# Average disparity for perceived_gender_presentation in concept Doctor: 0.2832
# Average disparity for has_facial_hair in concept Doctor: 0.0680
# Average disparity for has_tattoo in concept Doctor: 0.4096
# Average disparity for has_cap in concept Doctor: 0.0315
# Average disparity for has_mask in concept Doctor: 0.0190
# Average disparity for has_headscarf in concept Doctor: 0.0825
# Average disparity for has_eyeware in concept Doctor: 0.0309
# Average disparity for light_skin_indicator in concept Doctor: 0.0942
# Average disparity for hairtype in concept Farmer: 0.1381
# Average disparity for haircolor in concept Farmer: 0.1224
# Average disparity for perceived_age_presentation in concept Farmer: 0.0128
# Average disparity for perceived_gender_presentation in concept Farmer: 0.1370
# Average disparity for has_facial_hair in concept Farmer: 0.0209
# Average disparity for has_tattoo in concept Farmer: 0.0102
# Average disparity for has_cap in concept Farmer: 0.0689
# Average disparity for has_mask in concept Farmer: 0.0586
# Average disparity for has_headscarf in concept Farmer: 0.0536
# Average disparity for has_eyeware in concept Farmer: 0.0333
# Average disparity for light_skin_indicator in concept Farmer: 0.1045
# Average disparity for hairtype in concept Engineer: 0.1381
# Average disparity for haircolor in concept Engineer: 0.0528
# Average disparity for perceived_age_presentation in concept Engineer: 0.0722
# Average disparity for perceived_gender_presentation in concept Engineer: 0.0890
# Average disparity for has_facial_hair in concept Engineer: 0.0008
# Average disparity for has_tattoo in concept Engineer: 0.1139
# Average disparity for has_cap in concept Engineer: 0.2265
# Average disparity for has_mask in concept Engineer: 0.1141
# Average disparity for has_headscarf in concept Engineer: 0.1069
# Average disparity for has_eyeware in concept Engineer: 0.0717
# Average disparity for light_skin_indicator in concept Engineer: 0.0429
# Average disparity for hairtype in concept Waiter: 0.1456
# Average disparity for haircolor in concept Waiter: 0.0989
# Average disparity for perceived_age_presentation in concept Waiter: 0.0553
# Average disparity for perceived_gender_presentation in concept Waiter: 0.1426
# Average disparity for has_facial_hair in concept Waiter: 0.0301
# Average disparity for has_tattoo in concept Waiter: 0.0473
# Average disparity for has_cap in concept Waiter: 0.0754
# Average disparity for has_mask in concept Waiter: 0.0219
# Average disparity for has_headscarf in concept Waiter: 0.1187
# Average disparity for has_eyeware in concept Waiter: 0.0600
# Average disparity for light_skin_indicator in concept Waiter: 0.0111
# Average disparity for hairtype in concept Judge: 0.4422
# Average disparity for haircolor in concept Judge: 0.1720
# Average disparity for perceived_age_presentation in concept Judge: 0.0790
# Average disparity for perceived_gender_presentation in concept Judge: 0.1836
# Average disparity for has_facial_hair in concept Judge: 0.1037
# Average disparity for has_tattoo in concept Judge: 0.2153
# Average disparity for has_cap in concept Judge: 0.2348
# Average disparity for has_mask in concept Judge: 0.1181
# Average disparity for has_headscarf in concept Judge: 0.2153
# Average disparity for has_eyeware in concept Judge: 0.0856
# Average disparity for light_skin_indicator in concept Judge: 0.0254
# Average disparity for hairtype in concept Chef: 0.4402
# Average disparity for haircolor in concept Chef: 0.5456
# Average disparity for perceived_age_presentation in concept Chef: 0.2810
# Average disparity for perceived_gender_presentation in concept Chef: 0.4444
# Average disparity for has_facial_hair in concept Chef: 0.0747
# Average disparity for has_tattoo in concept Chef: 0.3496
# Average disparity for has_cap in concept Chef: 0.0913
# Average disparity for has_mask in concept Chef: 0.1825
# Average disparity for has_headscarf in concept Chef: 0.6899
# Average disparity for has_eyeware in concept Chef: 0.1023
# Average disparity for light_skin_indicator in concept Chef: 0.0919
# ======================================================================
# Average disparity in concept Police: 0.0693
# Average disparity in concept Mechanic: 0.0663
# Average disparity in concept Pilot: 0.2060
# Average disparity in concept Firefighter: 0.2649
# Average disparity in concept Doctor: 0.1705
# Average disparity in concept Farmer: 0.1094
# Average disparity in concept Engineer: 0.0936
# Average disparity in concept Waiter: 0.1076
# Average disparity in concept Judge: 0.2558
# Average disparity in concept Chef: 0.4313
# ======================================================================
# Overall average disparity across concepts: 0.1775
# ======================================================================
# Average disparity in attribute hairtype: 0.2170
# Average disparity in attribute haircolor: 0.1880
# Average disparity in attribute perceived_age_presentation: 0.0917
# Average disparity in attribute perceived_gender_presentation: 0.1887
# Average disparity in attribute has_facial_hair: 0.0445
# Average disparity in attribute has_tattoo: 0.2025
# Average disparity in attribute has_cap: 0.0879
# Average disparity in attribute has_mask: 0.0791
# Average disparity in attribute has_headscarf: 0.1570
# Average disparity in attribute has_eyeware: 0.0815
# Average disparity in attribute light_skin_indicator: 0.0623
# ======================================================================
# Overall average disparity across attributes: 0.1273
# ======================================================================

# %%
student_disparity_dict, student_concept_disparity_dict, student_mean_disparity_overall_concept, student_attribute_disparity_dict, student_mean_disparity_overall_attribute, _ = student_disparities
teacher_disparity_dict, teacher_concept_disparity_dict, teacher_mean_disparity_overall_concept, teacher_attribute_disparity_dict, teacher_mean_disparity_overall_attribute, _ = teacher_disparities

# %%
def plot_disparities(data_dict_student, data_dict_teacher, label_type):
    """
    Plots the mean absolute disparity bars for Teacher vs Student Models for either concepts or attributes.
    
    Args:
    - data_dict_student (dict): Dictionary of disparities for the student model.
    - data_dict_teacher (dict): Dictionary of disparities for the teacher model.
    - label_type (str): A descriptor ("Concepts" or "Attributes") to indicate what type of data is being plotted.
    """
    
    # Extracting disparities
    labels = list(data_dict_student.keys())
    student_disparities = list(data_dict_student.values())
    teacher_disparities = list(data_dict_teacher.values())

    # Setting up bar positions and width
    bar_width = 0.35
    index = np.arange(len(labels))

    # Plotting the data
    plt.figure(figsize=(12,6))
    bar1 = plt.bar(index, teacher_disparities, bar_width, label='Teacher', color='#1f77b4')  # Teacher is blue
    bar2 = plt.bar(index + bar_width, student_disparities, bar_width, label='Student', color='#ff7f0e')  # Student is orange

    # Adding data label values on top of each bar
    def add_labels(bars):
        for bar in bars:
            height = bar.get_height()
            plt.text(bar.get_x() + bar.get_width()/2., height, '%.3f' % height, ha='center', va='bottom', fontsize=9)

    add_labels(bar1)
    add_labels(bar2)

    # Labeling the chart
    plt.xlabel(label_type)
    plt.ylabel('Mean Absolute Disparity')
    plt.title(f'Mean Absolute Disparity by {label_type} for Teacher vs Student Model')
    plt.xticks(index + bar_width / 2, labels, rotation=90)
    plt.legend()

    # Displaying the plot
    plt.tight_layout()
    plt.show()

# Now call the function for both concepts and attributes
plot_disparities(student_concept_disparity_dict, teacher_concept_disparity_dict, 'Concepts')
plot_disparities(student_attribute_disparity_dict, teacher_attribute_disparity_dict, 'Attributes')

# %%
def plot_mean_absolute_disparity(disparities, descriptor):
    """
    Plots the mean absolute disparity for Teacher vs Student Models.
    
    Args:
    - disparities (list): List containing disparities for teacher and student.
    - descriptor (str): String describing the kind of disparities (e.g., "Across Concepts" or "Across Attributes").
    """
    
    # Data
    labels = ["Teacher", "Student"]
    colors = ['#1f77b4', '#ff7f0e']

    # Setting up the plot
    plt.figure(figsize=(8,6))

    # Creating bars
    bars = plt.bar(labels, disparities, color=colors)

    # Adding data label values on top of each bar
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2., height, '%.3f' % height, ha='center', va='bottom', fontsize=10)

    # Labeling the plot
    plt.ylabel('Mean Absolute Model Disparity')
    plt.title(f'Mean Absolute Model Disparity - {descriptor}: Teacher vs Student Model')
    plt.tight_layout()
    plt.show()

# Now call the function for both concepts and attributes
plot_mean_absolute_disparity([teacher_mean_disparity_overall_concept, student_mean_disparity_overall_concept], "Across Concepts")
plot_mean_absolute_disparity([teacher_mean_disparity_overall_attribute, student_mean_disparity_overall_attribute], "Across Attributes")

# %%
# Extract unique concepts and attribute-concept pairs for sorting
unique_concepts = set(pair[0] for pair in student_disparity_dict.keys())
sorted_pairs = sorted(student_disparity_dict.keys(), key=lambda x: (x[0], x[1]))


# Function to plot disparities for a given concept
def plot_disparities_for_concept(concept):
    # Filter out disparities for the given concept
    relevant_pairs = [pair for pair in sorted_pairs if pair[0] == concept]
    relevant_student_disparities = [student_disparity_dict[pair] for pair in relevant_pairs]
    relevant_teacher_disparities = [teacher_disparity_dict[pair] for pair in relevant_pairs]

    # Setting up the plot
    plt.figure(figsize=(10,5))

    # Setting bar width and positions
    bar_width = 0.35
    index = np.arange(len(relevant_pairs))

    # Creating bars
    bar1 = plt.bar(index, relevant_teacher_disparities, bar_width, label='Teacher')
    bar2 = plt.bar(index + bar_width, relevant_student_disparities, bar_width, label='Student')

    # Adding data label values on top of each bar
    def add_labels(bars):
        for bar in bars:
            height = bar.get_height()
            plt.text(bar.get_x() + bar.get_width()/2., height, '%.3f' % height, ha='center', va='bottom', fontsize=6)

    add_labels(bar1)
    add_labels(bar2)

    # Labeling the plot
    plt.xlabel('Attributes for ' + concept)
    plt.ylabel('Mean Absolute Disparity')
    plt.title(f'Mean Absolute Disparity by Attribute for {concept}: Teacher vs Student Model')

    # Setting x-axis labels to be attributes for the current concept
    labels = [pair[1] for pair in relevant_pairs]
    plt.xticks(index + bar_width / 2, labels, rotation=90)

    # Displaying the legend and the plot
    plt.legend()
    plt.tight_layout()
    plt.show()

# Loop through each unique concept and plot disparities for that concept
for concept in unique_concepts:
    plot_disparities_for_concept(concept)
